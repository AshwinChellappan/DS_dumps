# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\Admin\\Ashwin space'

# %%
df=pd.read_excel('MT103.xlsx')

# %%
df.head()
# Out:
#        MT103_SL_NO        SENDER      RECEIVER REFERENCE_NUMBER BANK_CODE  \
# 0  190919100094610  CHASUS33NXXX  KKBKINBBAXXX     1349343262FS      CRED
# 1  190920100095495  CITIUS33FXXX  KKBKINBBAXXX   S06926216A5701      CRED
# 2  190920100095496  SCBLDEFXAXXX  KKBKINBBAXXX     190920014940      CRED
# 3  190920100095498  CITIUS33EXXX  KKBKINBBAXXX   S0692611ED7A01      CRED
# 4  190918100092761  CITIUS33BXXX  KKBKINBBAXXX   S06926120EB701      CRED
#
#   VALUE_DATE CURRENCY_CODE    AMOUNT                     FILE_NAME STATUS  \
# 0  19-SEP-19           USD   3975.80  20190919204848686MT103.swift      A
# 1  20-SEP-19           USD   5021.00  20190920111447053MT103.swift      A
# 2  20-SEP-19           EUR  62382.30  20190920111404821MT103.swift      A
# 3  20-SEP-19           USD   6000.00  20190920111502729MT103.swift      A
# 4  18-SEP-19           USD    248.01  20190918195937169MT103.swift      A
#
#    ... CORROS_ID CTRL_STATUS PROCESSED_DATE PROCESSED_USER HOSTNAME UETR  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5428 entries, 0 to 5427
# Data columns (total 68 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   MT103_SL_NO            5428 non-null   int64
#  1   SENDER                 5428 non-null   object
#  2   RECEIVER               5428 non-null   object
#  3   REFERENCE_NUMBER       5428 non-null   object
#  4   BANK_CODE              5428 non-null   object
#  5   VALUE_DATE             5428 non-null   object
#  6   CURRENCY_CODE          5428 non-null   object
#  7   AMOUNT                 5428 non-null   float64
#  8   FILE_NAME              5428 non-null   object
#  9   STATUS                 5428 non-null   object
#  10  ORD_ACCNO              5420 non-null   object
#  11  ORD_NAME               5428 non-null   object
#  12  ORD_ADDR1              5427 non-null   object
#  13  ORD_ADDR2              5348 non-null   object
# ...

# %%
df[df['AMOUNT']<10]
# Out:
#           MT103_SL_NO        SENDER      RECEIVER  REFERENCE_NUMBER BANK_CODE  \
# 1802  190812100038181  PNBPUS3NBNYC  KKBKINBBAXXX   F60809358036000      CRED
# 2160  190812100038844  CHASUS33SXXX  KKBKINBBACPC      3317467224FS      CRED
# 2426  190812100038953  BARCGB22EXXX  KKBKINBBAXXX      PET413234224      CRED
# 4874  190813100041545  BOFAUS3NAXXX  KKBKINBBAXXX  2019080800317266      CRED
#
#      VALUE_DATE CURRENCY_CODE  AMOUNT                     FILE_NAME STATUS  \
# 1802  09-AUG-19           USD    0.01  20190813022244292MT103.swift      A
# 2160  12-AUG-19           USD    5.00  20190813041302085MT103.swift      P
# 2426  12-AUG-19           GBP    5.00  20190813033757793MT103.swift      A
# 4874  14-AUG-19           USD    1.00  20190814055153904MT103.swift      A
#
#       ... CORROS_ID CTRL_STATUS PROCESSED_DATE PROCESSED_USER HOSTNAME UETR  \
# 1802  ...       NaN           R            NaN            NaN      NaN  NaN
# ...

# %%
df[(df['AMOUNT']>1) & (df['AMOUNT']<10) ]
# Out:
#           MT103_SL_NO        SENDER      RECEIVER REFERENCE_NUMBER BANK_CODE  \
# 2160  190812100038844  CHASUS33SXXX  KKBKINBBACPC     3317467224FS      CRED
# 2426  190812100038953  BARCGB22EXXX  KKBKINBBAXXX     PET413234224      CRED
#
#      VALUE_DATE CURRENCY_CODE  AMOUNT                     FILE_NAME STATUS  \
# 2160  12-AUG-19           USD     5.0  20190813041302085MT103.swift      P
# 2426  12-AUG-19           GBP     5.0  20190813033757793MT103.swift      A
#
#       ... CORROS_ID CTRL_STATUS PROCESSED_DATE PROCESSED_USER HOSTNAME UETR  \
# 2160  ...       NaN           R            NaN            NaN      NaN  NaN
# 2426  ...       NaN           R            NaN            NaN      NaN  NaN
#
#      BALAMT SEN_CORRESPONDENT REC_CORRESPONDENT INTERMEDIARY_INS
# 2160    NaN               NaN               NaN              NaN
# 2426    NaN               NaN               NaN              NaN
#
# [2 rows x 68 columns]

# %%
df.iloc[2426]
# Out:
# MT103_SL_NO          190812100038953
# SENDER                  BARCGB22EXXX
# RECEIVER                KKBKINBBAXXX
# REFERENCE_NUMBER        PET413234224
# BANK_CODE                       CRED
#                           ...
# UETR                             NaN
# BALAMT                           NaN
# SEN_CORRESPONDENT                NaN
# REC_CORRESPONDENT                NaN
# INTERMEDIARY_INS                 NaN
# Name: 2426, Length: 68, dtype: object

# %%
df.BENEF_NO
# Out:
# 0         3211674923
# 1       7512 5852 47
# 2         3412799661
# 3         9512946653
# 4         4211618856
#             ...
# 5423    139011009852
# 5424      5712431395
# 5425      0112208639
# 5426      6012117156
# 5427    429011022970
# Name: BENEF_NO, Length: 5428, dtype: object

# %%
df.isnull()
df.notnull()
df.notna()
# Out:
#       MT103_SL_NO  SENDER  RECEIVER  REFERENCE_NUMBER  BANK_CODE  VALUE_DATE  \
# 0            True    True      True              True       True        True
# 1            True    True      True              True       True        True
# 2            True    True      True              True       True        True
# 3            True    True      True              True       True        True
# 4            True    True      True              True       True        True
# ...           ...     ...       ...               ...        ...         ...
# 5423         True    True      True              True       True        True
# 5424         True    True      True              True       True        True
# 5425         True    True      True              True       True        True
# 5426         True    True      True              True       True        True
# 5427         True    True      True              True       True        True
#
# ...

# %%
df['QUEUE_TYPE'].value_counts()
# Out:
# EXPQ     5248
# IC2RQ      54
# CLSQ       48
# IUNQ       38
# IOQ        26
# MANQ       11
# ISQ         3
# Name: QUEUE_TYPE, dtype: int64

# %%
df['AMOUNT'].rank()
# Out:
# 0       2107.0
# 1       2415.0
# 2       4880.0
# 3       2560.5
# 4        259.0
#          ...
# 5423    2026.0
# 5424    1289.0
# 5425     455.0
# 5426    2834.0
# 5427    2332.0
# Name: AMOUNT, Length: 5428, dtype: float64

# %%
df.sort_values('AMOUNT',ascending=False)
# Out:
#           MT103_SL_NO        SENDER      RECEIVER  REFERENCE_NUMBER BANK_CODE  \
# 247   190919100093854  MRMDUS33DXXX  KKBKINBBACUS         262400112      CRED
# 3858  190813100040511  IRVTUS3NWXXX  KKBKINBBAXXX  F9S1908138983400      CRED
# 4296  190813100040956  FIRNZAJJAXXX  KKBKINBBAXXX  S657DF1073112799      CRED
# 3760  190813100040988  CHASUS33TXXX  KKBKINBBACPC      5730600225FC      CRED
# 5301  190813100041373  IRVTUS3NQXXX  KKBKINBBAXXX  FDF1908131654300      CRED
# ...               ...           ...           ...               ...       ...
# 2117  190812100039453  DEUTDEFFGXXX  KKBKINBBAXXX  03MT190812143091      CRED
# 2160  190812100038844  CHASUS33SXXX  KKBKINBBACPC      3317467224FS      CRED
# 2426  190812100038953  BARCGB22EXXX  KKBKINBBAXXX      PET413234224      CRED
# 4874  190813100041545  BOFAUS3NAXXX  KKBKINBBAXXX  2019080800317266      CRED
# 1802  190812100038181  PNBPUS3NBNYC  KKBKINBBAXXX   F60809358036000      CRED
#
# ...

# %%
df[['AMOUNT','CURRENCY_CODE','BENEF_NO']].sort_values('AMOUNT')
# Out:
#            AMOUNT CURRENCY_CODE        BENEF_NO
# 1802         0.01           USD    550044011089
# 4874         1.00           USD      3012840541
# 2160         5.00           USD       400913062
# 2426         5.00           GBP      0912567523
# 2117        10.00           EUR      5911987052
# ...           ...           ...             ...
# 5301   9537546.00           USD      2911815780
# 3760  11000000.00           USD      1611908631
# 4296  16003909.86           ZAR  01722560002523
# 3858  19999985.00           USD      9011649260
# 247   20572000.00           USD       400913062
#
# [5428 rows x 3 columns]

# %%
df[df['AMOUNT']<15]
# Out:
#           MT103_SL_NO        SENDER      RECEIVER  REFERENCE_NUMBER BANK_CODE  \
# 1376  190812100037787  SCBLGB2LAXXX  KKBKINBBAXXX  RBH090890LK90JCW      CRED
# 1802  190812100038181  PNBPUS3NBNYC  KKBKINBBAXXX   F60809358036000      CRED
# 2117  190812100039453  DEUTDEFFGXXX  KKBKINBBAXXX  03MT190812143091      CRED
# 2160  190812100038844  CHASUS33SXXX  KKBKINBBACPC      3317467224FS      CRED
# 2207  190812100038806  ESSESESSDXXX  KKBKINBBAXXX   USI5560-7139245      CRED
# 2426  190812100038953  BARCGB22EXXX  KKBKINBBAXXX      PET413234224      CRED
# 4874  190813100041545  BOFAUS3NAXXX  KKBKINBBAXXX  2019080800317266      CRED
#
#      VALUE_DATE CURRENCY_CODE  AMOUNT                     FILE_NAME STATUS  \
# 1376  09-AUG-19           GBP   13.67  20190813010233453MT103.swift      A
# 1802  09-AUG-19           USD    0.01  20190813022244292MT103.swift      A
# 2117  12-AUG-19           EUR   10.00  20190813034149637MT103.swift      A
# ...

# %%
df.rename(columns={'MT103_SL_NO':'SERIALNO'},inplace=True)

# %%
df.head()
# Out:
#           SERIALNO        SENDER      RECEIVER REFERENCE_NUMBER BANK_CODE  \
# 0  190919100094610  CHASUS33NXXX  KKBKINBBAXXX     1349343262FS      CRED
# 1  190920100095495  CITIUS33FXXX  KKBKINBBAXXX   S06926216A5701      CRED
# 2  190920100095496  SCBLDEFXAXXX  KKBKINBBAXXX     190920014940      CRED
# 3  190920100095498  CITIUS33EXXX  KKBKINBBAXXX   S0692611ED7A01      CRED
# 4  190918100092761  CITIUS33BXXX  KKBKINBBAXXX   S06926120EB701      CRED
#
#   VALUE_DATE CURRENCY_CODE    AMOUNT                     FILE_NAME STATUS  \
# 0  19-SEP-19           USD   3975.80  20190919204848686MT103.swift      A
# 1  20-SEP-19           USD   5021.00  20190920111447053MT103.swift      A
# 2  20-SEP-19           EUR  62382.30  20190920111404821MT103.swift      A
# 3  20-SEP-19           USD   6000.00  20190920111502729MT103.swift      A
# 4  18-SEP-19           USD    248.01  20190918195937169MT103.swift      A
#
#    ... CORROS_ID CTRL_STATUS PROCESSED_DATE PROCESSED_USER HOSTNAME UETR  \
# ...

# %%
df.drop(['BENEF_ADDR1','BENEF_ADDR2','BENEF_ADDR3','ORD_ADDR1','ORD_ADDR2','ORD_ADDR3'],axis=1,inplace=True)

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5428 entries, 0 to 5427
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SERIALNO          5428 non-null   int64
#  1   SENDER            5428 non-null   object
#  2   REFERENCE_NUMBER  5428 non-null   object
#  3   BANK_CODE         5428 non-null   object
#  4   VALUE_DATE        5428 non-null   object
#  5   CURRENCY_CODE     5428 non-null   object
#  6   AMOUNT            5428 non-null   float64
#  7   FILE_NAME         5428 non-null   object
#  8   STATUS            5428 non-null   object
#  9   ORD_ACCNO         5420 non-null   object
#  10  ORD_NAME          5428 non-null   object
#  11  BENEF_NO          5418 non-null   object
#  12  BENEF_NAME        5428 non-null   object
#  13  ORD_INS           4439 non-null   object
#  14  REM_INFO          4993 non-null   object
#  15  SENDER_RECEVIER   1924 non-null   object
# ...

# %%
df.groupby(['BENEF_NO','AMOUNT'])['QUEUE_TYPE'].count()
# Out:
# BENEF_NO              AMOUNT
# 0 89792080000018      180.68       1
# 00000000002311468449  7000.00      1
# 0000006699            290083.60    1
# 00004454711942628     6508.38      1
# 000201516755          6000.00      1
#                                   ..
# NRE5912868830         248.39       1
# NRE9511577940         2255.00      1
# NRESB2513246807       3500.00      1
# NRESB548010059338     7400.00      1
# NRESB548010061619     3000.00      1
# Name: QUEUE_TYPE, Length: 5367, dtype: int64

# %%
df.groupby(['AMOUNT'].filter(lambda x : AMOUNT <15))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-0e10726c17c1> in <module>
# ----> 1 df.groupby(['AMOUNT'].filter(lambda x : AMOUNT <15))
#
# AttributeError: 'list' object has no attribute 'filter'

# %%
df.groupby(['AMOUNT']).filter(lambda x: df['AMOUNT'].count()==1)
# Out:
# Empty DataFrame
# Columns: [SERIALNO, SENDER, REFERENCE_NUMBER, BANK_CODE, VALUE_DATE, CURRENCY_CODE, AMOUNT, FILE_NAME, STATUS, ORD_ACCNO, ORD_NAME, BENEF_NO, BENEF_NAME, ORD_INS, REM_INFO, SENDER_RECEVIER, QUEUE_TYPE, CREATED_DATE, MESSAGE_DATA, PROCESS_TYPE, CH_BEN_ACC_NO]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.groupby('BENEF_NO')['AMOUNT'].groups
# Out:
# BENEF_NO
# 0 89792080000018           180.68
# 00000000002311468449      7000.00
# 0000006699              290083.60
# 00004454711942628         6508.38
# 000201516755              6000.00
#                           ...
# NRE5912868830              248.39
# NRE9511577940             2255.00
# NRESB2513246807           3500.00
# NRESB548010059338         7400.00
# NRESB548010061619         3000.00
# Name: AMOUNT, Length: 3447, dtype: float64

# %%
x=df.groupby('BENEF_NO')['AMOUNT'].sum().head(30)
for key, values in x:
    print(df[values])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-4ee6bffe682b> in <module>
#       1 x=df.groupby('BENEF_NO')['AMOUNT'].sum().head(30)
# ----> 2 for key, values in x:
#       3     print(df[values])
#
# TypeError: cannot unpack non-iterable float object

# %%
for key, values in df.iteritems():
        print(df.items)
# Out:
# <bound method DataFrame.items of              SERIALNO        SENDER  REFERENCE_NUMBER BANK_CODE VALUE_DATE  \
# 0     190919100094610  CHASUS33NXXX      1349343262FS      CRED  19-SEP-19
# 1     190920100095495  CITIUS33FXXX    S06926216A5701      CRED  20-SEP-19
# 2     190920100095496  SCBLDEFXAXXX      190920014940      CRED  20-SEP-19
# 3     190920100095498  CITIUS33EXXX    S0692611ED7A01      CRED  20-SEP-19
# 4     190918100092761  CITIUS33BXXX    S06926120EB701      CRED  18-SEP-19
# ...               ...           ...               ...       ...        ...
# 5423  190814100042712  COBADEFFBXXX  AZMA922605633700      CRED  16-AUG-19
# 5424  190814100042510  AIBKIE2DAXXX  IE19081413659755      CRED  15-AUG-19
# 5425  190814100042520  IRVTUS3NHXXX  FTS1908148728100      CRED  14-AUG-19
# 5426  190814100042548  CITIUS33DXXX    S0692261422C01      CRED  14-AUG-19
# 5427  190814100042241  COBADEFFHXXX  AZNA922603109100      CRED  16-AUG-19
#
# ...
