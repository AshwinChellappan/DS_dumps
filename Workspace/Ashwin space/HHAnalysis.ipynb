# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('D:\\DataScience\\Projectspace\\H&H analysis.xlsx')

# %%
df.head()
# Out:
#    SL NO                   PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0    1.0             APGEL GEL 10GM           11     1.0          NaN
# 1    2.0        CLONATE LOTION 25ML            6     5.0          NaN
# 2    3.0          CLONATE OINT 20GM            3     4.0          1.0
# 3    4.0          CLONATE OINT 30GM           19     2.0          NaN
# 4    5.0  DERMADEW BABY LOTION 80ML            4    65.0          NaN
#
#    R.BALAJI  SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  \
# 0       1.0                             2.0         28.0       NaN
# 1       NaN                             2.0         27.0       NaN
# 2       2.0                             2.0         14.0       NaN
# 3       2.0                             2.0          2.0       1.0
# 4       2.0                             1.0         14.0       2.0
#
#    KRISHNARAJA  ...  P.SURESH  SARATHKUMAR  ANBARASAN  BHUVANESH  BALAMURUGAN  \
# ...

# %%
df.dtypes
# Out:
# SL NO                             float64
# PRODUCTS                           object
# GROSS SALES                         int64
# NELSON                            float64
# JEYAMURUGAN                       float64
# R.BALAJI                          float64
# SYED MOHAMMED JUBAIRALI.C.M.R.    float64
# YOKESHWARAN                       float64
# A.BALAJI                          float64
# KRISHNARAJA                       float64
# LOGANATHAN                        float64
# P.SURESH                          float64
# SARATHKUMAR                       float64
# ANBARASAN                         float64
# BHUVANESH                         float64
# BALAMURUGAN                       float64
# BOY NAME 14                       float64
# BOY NAME 15                       float64
# BOY NAME 16                       float64
# TOTAL                               int64
# difference                          int64
# dtype: object

# %%
df.describe()
# Out:
#            SL NO  GROSS SALES      NELSON  JEYAMURUGAN  R.BALAJI  \
# count  35.000000    36.000000   25.000000     9.000000  16.00000
# mean   18.000000    11.277778   46.960000     3.333333   7.37500
# std    10.246951    34.158965  120.510539     5.196152  14.46778
# min     1.000000     0.000000    1.000000    -1.000000   1.00000
# 25%     9.500000     0.000000    2.000000     1.000000   2.00000
# 50%    18.000000     3.000000    7.000000     1.000000   2.00000
# 75%    26.500000     6.500000   30.000000     2.000000   6.00000
# max    35.000000   203.000000  587.000000    15.000000  59.00000
#
#        SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  KRISHNARAJA  \
# count                       19.000000    27.000000  6.000000     4.000000
# mean                        14.315789    36.740741  2.333333     2.000000
# std                         31.210847    95.041122  2.338090     1.414214
# min                          1.000000     1.000000  1.000000     1.000000
# ...

# %%
df.shape
# Out:
# (36, 21)

# %%
df.info
# Out:
# <bound method DataFrame.info of     SL NO                      PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0     1.0                APGEL GEL 10GM           11     1.0          NaN
# 1     2.0           CLONATE LOTION 25ML            6     5.0          NaN
# 2     3.0             CLONATE OINT 20GM            3     4.0          1.0
# 3     4.0             CLONATE OINT 30GM           19     2.0          NaN
# 4     5.0     DERMADEW BABY LOTION 80ML            4    65.0          NaN
# 5     6.0       DERMADEW BABY SOAP 75GM           48   211.0          1.0
# 6     7.0      DERMADEW FACE WASH 100ML            0    20.0          1.0
# 7     8.0      DERMADEW GLOW CREAM 50GM            3     NaN          NaN
# 8     9.0    DKGEL DUSTING POWDER 100GM            2    40.0          NaN
# 9    10.0                DKGEL GEL 30GM           19    26.0          2.0
# 10   11.0             DKGEL-XL GEL 50GM            0     NaN          NaN
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     SL NO                      PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0     1.0                APGEL GEL 10GM           11     1.0          NaN
# 1     2.0           CLONATE LOTION 25ML            6     5.0          NaN
# 2     3.0             CLONATE OINT 20GM            3     4.0          1.0
# 3     4.0             CLONATE OINT 30GM           19     2.0          NaN
# 4     5.0     DERMADEW BABY LOTION 80ML            4    65.0          NaN
# 5     6.0       DERMADEW BABY SOAP 75GM           48   211.0          1.0
# 6     7.0      DERMADEW FACE WASH 100ML            0    20.0          1.0
# 7     8.0      DERMADEW GLOW CREAM 50GM            3     NaN          NaN
# 8     9.0    DKGEL DUSTING POWDER 100GM            2    40.0          NaN
# 9    10.0                DKGEL GEL 30GM           19    26.0          2.0
# 10   11.0             DKGEL-XL GEL 50GM            0     NaN          NaN
# ...

# %%
df.drop(0,inplace=True)

# %%
df.head()
# Out:
#    SL NO                   PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0    1.0             APGEL GEL 10GM           11     1.0          NaN
# 1    2.0        CLONATE LOTION 25ML            6     5.0          NaN
# 2    3.0          CLONATE OINT 20GM            3     4.0          1.0
# 3    4.0          CLONATE OINT 30GM           19     2.0          NaN
# 4    5.0  DERMADEW BABY LOTION 80ML            4    65.0          NaN
#
#    R.BALAJI  SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  \
# 0       1.0                             2.0         28.0       NaN
# 1       NaN                             2.0         27.0       NaN
# 2       2.0                             2.0         14.0       NaN
# 3       2.0                             2.0          2.0       1.0
# 4       2.0                             1.0         14.0       2.0
#
#    KRISHNARAJA  ...  P.SURESH  SARATHKUMAR  ANBARASAN  BHUVANESH  BALAMURUGAN  \
# ...

# %%
df.groupby('PRODUCTS')['YOKESHWARAN'].count()
# Out:
# PRODUCTS
# APGEL GEL 10GM                  1
# CLONATE LOTION 25ML             1
# CLONATE OINT 20GM               1
# CLONATE OINT 30GM               1
# DERMADEW BABY LOTION 80ML       1
# DERMADEW BABY SOAP 75GM         1
# DERMADEW FACE WASH 100ML        1
# DERMADEW GLOW CREAM 50GM        1
# DKGEL DUSTING POWDER 100GM      1
# DKGEL GEL 30GM                  1
# DKGEL-XL GEL 50GM               0
# FUDIC BNF CREAM 10GM            1
# FUDIC BNF CREAM 20GM            0
# FZHH TABLET 150MG (DPCO)        1
# HHCEPO - CV 325MG TABLET        0
# HHCEPO - CV DRY SYRUP 30ML      1
# HHCEPO 100 DRY SYRUP 30ML       1
# HHCEPO 100 DT                   0
# HHCEPO 200 TABLET               1
# HHCEPO DRY SYRUP 30ML           0
# HHFEXO-M SUSPENSION 60ML        0
# HHFEXO-M TABLET                 1
# HHLINCTUS JUNIOR SYRUP 100ML    1
# HHLINCTUS SYRUP 100ML           1
# HHSALIC 6 OINT 10GM             1
# HHSALIC LOTION 10ML             1
# HHSALIC OINT 10GM               1
# ...

# %%
df.iloc[:]['YOKESHWARAN'].count()
# Out:
# 27

# %%
df.loc[1:10]['YOKESHWARAN'].sum()
# Out:
# 150.0

# %%
df.loc[1:10]['PRODUCTS']
df.iloc[:,[1,2,7,19]]
# Out:
#                         PRODUCTS  GROSS SALES  YOKESHWARAN  TOTAL
# 0                 APGEL GEL 10GM           11         28.0     36
# 1            CLONATE LOTION 25ML            6         27.0     51
# 2              CLONATE OINT 20GM            3         14.0     39
# 3              CLONATE OINT 30GM           19          2.0     26
# 4      DERMADEW BABY LOTION 80ML            4         14.0     83
# 5        DERMADEW BABY SOAP 75GM           48         66.0    459
# 6       DERMADEW FACE WASH 100ML            0          4.0     31
# 7       DERMADEW GLOW CREAM 50GM            3          2.0      1
# 8     DKGEL DUSTING POWDER 100GM            2          3.0     43
# 9                 DKGEL GEL 30GM           19         18.0    107
# 10             DKGEL-XL GEL 50GM            0          NaN      0
# 11          FUDIC BNF CREAM 10GM            5          7.0     29
# 12          FUDIC BNF CREAM 20GM            0          NaN     14
# ...

# %%
df[['PRODUCTS','GROSS SALES','YOKESHWARAN','TOTAL']]
# Out:
#                         PRODUCTS  YOKESHWARAN  TOTAL
# 0                 APGEL GEL 10GM         28.0     36
# 1            CLONATE LOTION 25ML         27.0     51
# 2              CLONATE OINT 20GM         14.0     39
# 3              CLONATE OINT 30GM          2.0     26
# 4      DERMADEW BABY LOTION 80ML         14.0     83
# 5        DERMADEW BABY SOAP 75GM         66.0    459
# 6       DERMADEW FACE WASH 100ML          4.0     31
# 7       DERMADEW GLOW CREAM 50GM          2.0      1
# 8     DKGEL DUSTING POWDER 100GM          3.0     43
# 9                 DKGEL GEL 30GM         18.0    107
# 10             DKGEL-XL GEL 50GM          NaN      0
# 11          FUDIC BNF CREAM 10GM          7.0     29
# 12          FUDIC BNF CREAM 20GM          NaN     14
# 13      FZHH TABLET 150MG (DPCO)         59.0    114
# 14      HHCEPO - CV 325MG TABLET          NaN      8
# 15    HHCEPO - CV DRY SYRUP 30ML          1.0      1
# 16     HHCEPO 100 DRY SYRUP 30ML         18.0     23
# ...

# %%
df[df['YOKESHWARAN']<10][['PRODUCTS','YOKESHWARAN']]
# Out:
#                        PRODUCTS  YOKESHWARAN
# 3             CLONATE OINT 30GM          2.0
# 6      DERMADEW FACE WASH 100ML          4.0
# 7      DERMADEW GLOW CREAM 50GM          2.0
# 8    DKGEL DUSTING POWDER 100GM          3.0
# 11         FUDIC BNF CREAM 10GM          7.0
# 15   HHCEPO - CV DRY SYRUP 30ML          1.0
# 18            HHCEPO 200 TABLET          1.0
# 24          HHSALIC 6 OINT 10GM          3.0
# 25          HHSALIC LOTION 10ML          2.0
# 26            HHSALIC OINT 10GM          8.0
# 27            HHSALIC OINT 20GM          1.0
# 29  MX-10 TOPICAL SOLUTION 60ML          1.0
# 31   MX-5 TOPICAL SOLUTION 60ML          4.0
# 32  PROTEININA KID POWDER 200GM          6.0

# %%
df[df['YOKESHWARAN']>10][['PRODUCTS','YOKESHWARAN']].max()
# Out:
# PRODUCTS       TOTAL
# YOKESHWARAN      496
# dtype: object

# %%
df.YOKESHWARAN
# Out:
# 0      28.0
# 1      27.0
# 2      14.0
# 3       2.0
# 4      14.0
# 5      66.0
# 6       4.0
# 7       2.0
# 8       3.0
# 9      18.0
# 10      NaN
# 11      7.0
# 12      NaN
# 13     59.0
# 14      NaN
# 15      1.0
# 16     18.0
# 17      NaN
# 18      1.0
# 19      NaN
# 20      NaN
# 21    106.0
# 22     31.0
# 23     39.0
# 24      3.0
# 25      2.0
# 26      8.0
# 27      1.0
# 28     31.0
# 29      1.0
# 30      NaN
# 31      4.0
# 32      6.0
# 33      NaN
# 34      NaN
# 35    496.0
# Name: YOKESHWARAN, dtype: float64

# %%
df1=df.drop('TOTAL',axis=1)
df.tail()
# Out:
#     SL NO                     PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 31   32.0   MX-5 TOPICAL SOLUTION 60ML            5     NaN          1.0
# 32   33.0  PROTEININA KID POWDER 200GM            0    20.0          NaN
# 33   34.0        SUNBAN ULTRA GEL 60GM            0     NaN          NaN
# 34   35.0              SZHH CREAM 30GM            4     NaN          NaN
# 35    NaN                        TOTAL          203   587.0         15.0
#
#     R.BALAJI  SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  \
# 31       NaN                             NaN          4.0       NaN
# 32       NaN                             NaN          6.0       NaN
# 33       NaN                             NaN          NaN       NaN
# 34       NaN                             NaN          NaN       NaN
# 35      59.0                           136.0        496.0       7.0
#
#     KRISHNARAJA  ...  P.SURESH  SARATHKUMAR  ANBARASAN  BHUVANESH  \
# ...

# %%
df.dropna(axis=1,how='any')
df.dropna(subset=['SL NO'])
# Out:
#     SL NO                      PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0     1.0                APGEL GEL 10GM           11     1.0          NaN
# 1     2.0           CLONATE LOTION 25ML            6     5.0          NaN
# 2     3.0             CLONATE OINT 20GM            3     4.0          1.0
# 3     4.0             CLONATE OINT 30GM           19     2.0          NaN
# 4     5.0     DERMADEW BABY LOTION 80ML            4    65.0          NaN
# 5     6.0       DERMADEW BABY SOAP 75GM           48   211.0          1.0
# 6     7.0      DERMADEW FACE WASH 100ML            0    20.0          1.0
# 7     8.0      DERMADEW GLOW CREAM 50GM            3     NaN          NaN
# 8     9.0    DKGEL DUSTING POWDER 100GM            2    40.0          NaN
# 9    10.0                DKGEL GEL 30GM           19    26.0          2.0
# 10   11.0             DKGEL-XL GEL 50GM            0     NaN          NaN
# 11   12.0          FUDIC BNF CREAM 10GM            5     5.0         -1.0
# ...

# %%
df.dropna(subset=['SL NO'],inplace=True)

# %%
df.tail()
# Out:
#     SL NO                     PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 30   31.0   MX-2 TOPICAL SOLUTION 60ML            3     1.0          NaN
# 31   32.0   MX-5 TOPICAL SOLUTION 60ML            5     NaN          1.0
# 32   33.0  PROTEININA KID POWDER 200GM            0    20.0          NaN
# 33   34.0        SUNBAN ULTRA GEL 60GM            0     NaN          NaN
# 34   35.0              SZHH CREAM 30GM            4     NaN          NaN
#
#     R.BALAJI  SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  \
# 30       7.0                             NaN          NaN       NaN
# 31       NaN                             NaN          4.0       NaN
# 32       NaN                             NaN          6.0       NaN
# 33       NaN                             NaN          NaN       NaN
# 34       NaN                             NaN          NaN       NaN
#
#     KRISHNARAJA  ...  P.SURESH  SARATHKUMAR  ANBARASAN  BHUVANESH  \
# ...

# %%
df[ (df['YOKESHWARAN']>10) & (df['YOKESHWARAN']<30) ][:]
# Out:
#     SL NO                   PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0     1.0             APGEL GEL 10GM           11     1.0          NaN
# 1     2.0        CLONATE LOTION 25ML            6     5.0          NaN
# 2     3.0          CLONATE OINT 20GM            3     4.0          1.0
# 4     5.0  DERMADEW BABY LOTION 80ML            4    65.0          NaN
# 9    10.0             DKGEL GEL 30GM           19    26.0          2.0
# 16   17.0  HHCEPO 100 DRY SYRUP 30ML            1     2.0          NaN
#
#     R.BALAJI  SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  \
# 0        1.0                             2.0         28.0       NaN
# 1        NaN                             2.0         27.0       NaN
# 2        2.0                             2.0         14.0       NaN
# 4        2.0                             1.0         14.0       2.0
# 9        4.0                            15.0         18.0       1.0
# ...

# %%
df.sort_values(['YOKESHWARAN','NELSON'])
#df.notnull(df.sort_values('YOKESHWARAN'))
# Out:
#     SL NO                      PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 27   28.0             HHSALIC OINT 20GM            1     2.0          NaN
# 29   30.0   MX-10 TOPICAL SOLUTION 60ML            5     2.0          NaN
# 18   19.0             HHCEPO 200 TABLET            1    53.0          NaN
# 15   16.0    HHCEPO - CV DRY SYRUP 30ML            0     NaN          NaN
# 3     4.0             CLONATE OINT 30GM           19     2.0          NaN
# 7     8.0      DERMADEW GLOW CREAM 50GM            3     NaN          NaN
# 25   26.0           HHSALIC LOTION 10ML            1     NaN          NaN
# 8     9.0    DKGEL DUSTING POWDER 100GM            2    40.0          NaN
# 24   25.0           HHSALIC 6 OINT 10GM            0     NaN          NaN
# 6     7.0      DERMADEW FACE WASH 100ML            0    20.0          1.0
# 31   32.0    MX-5 TOPICAL SOLUTION 60ML            5     NaN          1.0
# 32   33.0   PROTEININA KID POWDER 200GM            0    20.0          NaN
# ...

# %%
df[df['YOKESHWARAN']>10].sort_values('YOKESHWARAN',ascending=False)
# Out:
#     SL NO                      PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 21   22.0               HHFEXO-M TABLET            0     2.0          NaN
# 5     6.0       DERMADEW BABY SOAP 75GM           48   211.0          1.0
# 13   14.0      FZHH TABLET 150MG (DPCO)           17    30.0          NaN
# 23   24.0         HHLINCTUS SYRUP 100ML           15    56.0          1.0
# 22   23.0  HHLINCTUS JUNIOR SYRUP 100ML            0     NaN          NaN
# 28   29.0                KZ LOTION 50ML           17    10.0          9.0
# 0     1.0                APGEL GEL 10GM           11     1.0          NaN
# 1     2.0           CLONATE LOTION 25ML            6     5.0          NaN
# 9    10.0                DKGEL GEL 30GM           19    26.0          2.0
# 16   17.0     HHCEPO 100 DRY SYRUP 30ML            1     2.0          NaN
# 2     3.0             CLONATE OINT 20GM            3     4.0          1.0
# 4     5.0     DERMADEW BABY LOTION 80ML            4    65.0          NaN
#
# ...

# %%
df['rank']=df.TOTAL

# %%
df.drop(columns='rank',inplace=True)

# %%
df['rank']=df.TOTAL.rank(method='min')

# %%
df.sort_values('rank',ascending=False)
# Out:
#     SL NO                      PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 5     6.0       DERMADEW BABY SOAP 75GM           48   211.0          1.0
# 23   24.0         HHLINCTUS SYRUP 100ML           15    56.0          1.0
# 13   14.0      FZHH TABLET 150MG (DPCO)           17    30.0          NaN
# 28   29.0                KZ LOTION 50ML           17    10.0          9.0
# 21   22.0               HHFEXO-M TABLET            0     2.0          NaN
# 9    10.0                DKGEL GEL 30GM           19    26.0          2.0
# 4     5.0     DERMADEW BABY LOTION 80ML            4    65.0          NaN
# 18   19.0             HHCEPO 200 TABLET            1    53.0          NaN
# 1     2.0           CLONATE LOTION 25ML            6     5.0          NaN
# 8     9.0    DKGEL DUSTING POWDER 100GM            2    40.0          NaN
# 2     3.0             CLONATE OINT 20GM            3     4.0          1.0
# 0     1.0                APGEL GEL 10GM           11     1.0          NaN
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(df['PRODUCTS'],df['TOTAL'],color='red')
#plt.plot(df['YOKESHWARAN'],df['TOTAL'],color='green')
plt.title('PRODUCT TREND')
plt.xlabel('PRODUCTS')
plt.ylabel('TOTAL')
plt.grid()
plt.show()

# %%
df.head()
# Out:
#    SL NO                   PRODUCTS  GROSS SALES  NELSON  JEYAMURUGAN  \
# 0    1.0             APGEL GEL 10GM           11     1.0          NaN
# 1    2.0        CLONATE LOTION 25ML            6     5.0          NaN
# 2    3.0          CLONATE OINT 20GM            3     4.0          1.0
# 3    4.0          CLONATE OINT 30GM           19     2.0          NaN
# 4    5.0  DERMADEW BABY LOTION 80ML            4    65.0          NaN
#
#    R.BALAJI  SYED MOHAMMED JUBAIRALI.C.M.R.  YOKESHWARAN  A.BALAJI  \
# 0       1.0                             2.0         28.0       NaN
# 1       NaN                             2.0         27.0       NaN
# 2       2.0                             2.0         14.0       NaN
# 3       2.0                             2.0          2.0       1.0
# 4       2.0                             1.0         14.0       2.0
#
#    KRISHNARAJA  ...  SARATHKUMAR  ANBARASAN  BHUVANESH  BALAMURUGAN  \
# 0          2.0  ...          NaN        1.0        1.0          NaN
# ...
