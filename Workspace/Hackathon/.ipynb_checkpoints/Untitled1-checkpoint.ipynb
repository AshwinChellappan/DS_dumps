# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
data=pd.read_csv('Train_dataset.csv')
data.head()
# Out:
#    Registration Number  Annual Turnover           Cuisine       City  \
# 0                60001         42000000      indian,irish  Bangalore
# 1                60002         50000000      indian,irish     Indore
# 2                60003         32500000   tibetan,italian    Chennai
# 3                60004        110000000  turkish,nigerian    Gurgaon
# 4                60005         20000000     irish,belgian    Manesar
#
#   Restaurant Location Opening Day of Restaurant  Facebook Popularity Quotient  \
# 0   Near Business Hub                14-02-2009                          84.3
# 1      Near Party Hub                29-09-2008                          85.4
# 2   Near Business Hub                30-07-2011                          85.0
# 3      Near Party Hub                30-11-2008                          85.6
# 4      Near Party Hub                22-02-2010                           NaN
#
#         Endorsed By  Instagram Popularity Quotient  Fire Audit  ...  \
# 0      Not Specific                           95.8           1  ...
# 1  Tier A Celebrity                           85.0           1  ...
# 2  Tier A Celebrity                           68.2           1  ...
# 3  Tier A Celebrity                           83.6           0  ...
# 4  Tier A Celebrity                           76.8           1  ...
#
#    Overall Restaurant Rating  Live Music Rating  Comedy Gigs Rating  \
# 0                       10.0                4.0                 NaN
# 1                        9.0                NaN                 4.0
# 2                        8.0                3.0                 NaN
# 3                        9.0                6.0                 NaN
# 4                        6.0                NaN                 2.0
#
#    Value Deals Rating  Live Sports Rating Ambience Lively  Service  \
# 0                 NaN                 NaN      8.0      8        6
# 1                 NaN                 NaN      5.0      7        7
# 2                 NaN                 NaN      7.0     10        5
# 3                 NaN                 NaN      7.0      7        4
# 4                 NaN                 NaN      NaN      6        2
#
#    Comfortablility  Privacy
# 0                6        6
# 1                3        8
# 2                2        8
# 3                3        5
# 4                4        6
#
# [5 rows x 34 columns]

# %%
Total=data.isnull().sum().sort_values(ascending=False)  
Total
percent=(data.isnull().sum()*100/data.isnull().count()).sort_values(ascending=False)
percent
missing_data = pd.concat([Total, percent], axis=1, keys=['Total', 'Percent'])    
missing_data

#['Value Deals Rating','Comedy Gigs Rating','Live Music Rating','Overall Restaurant Rating','Facebook Popularity Quotient','Instagram Popularity Quotient','Resturant Tie','Ambience']
# Out:
#                                Total    Percent
# Live Sports Rating              3288  94.131119
# Value Deals Rating              2707  77.497853
# Comedy Gigs Rating              2483  71.085027
# Live Music Rating                765  21.900945
# Overall Restaurant Rating        212   6.069281
# Facebook Popularity Quotient      99   2.834240
# Instagram Popularity Quotient     56   1.603206
# Resturant Tier                    49   1.402806
# Ambience                          25   0.715717
# Situated in a Multi Complex        0   0.000000
# Liquor License Obtained            0   0.000000
# Fire Audit                         0   0.000000
# Endorsed By                        0   0.000000
# Privacy                            0   0.000000
# Opening Day of Restaurant          0   0.000000
# Restaurant Location                0   0.000000
# Dedicated Parking                  0   0.000000
# Cuisine                            0   0.000000
# Annual Turnover                    0   0.000000
# City                               0   0.000000
# Restaurant Theme                   0   0.000000
# Open Sitting Available             0   0.000000
# Restaurant Type                    0   0.000000
# Comfortablility                    0   0.000000
# Restaurant Zomato Rating           0   0.000000
# Restaurant City Tier               0   0.000000
# Order Wait Time                    0   0.000000
# Staff Responsivness                0   0.000000
# Value for Money                    0   0.000000
# Hygiene Rating                     0   0.000000
# Food Rating                        0   0.000000
# Lively                             0   0.000000
# Service                            0   0.000000
# Registration Number                0   0.000000

# %%
#data=data.drop(columns=['Live Sports Rating','Value Deals Rating','Comedy Gigs Rating'],axis=0)
data=data.drop(columns=['Opening Day of Restaurant'],axis=0)#'Live Sports Rating',

# %%
data.head(2)
# Out:
#    Registration Number  Annual Turnover       Cuisine       City  \
# 0                60001         42000000  indian,irish  Bangalore
# 1                60002         50000000  indian,irish     Indore
#
#   Restaurant Location Opening Day of Restaurant  Facebook Popularity Quotient  \
# 0   Near Business Hub                14-02-2009                          84.3
# 1      Near Party Hub                29-09-2008                          85.4
#
#         Endorsed By  Instagram Popularity Quotient  Fire Audit  ...  \
# 0      Not Specific                           95.8           1  ...
# 1  Tier A Celebrity                           85.0           1  ...
#
#    Food Rating  Overall Restaurant Rating  Live Music Rating  \
# 0            7                       10.0                4.0
# 1            8                        9.0                NaN
#
#    Comedy Gigs Rating  Value Deals Rating Ambience Lively  Service  \
# 0                 NaN                 NaN      8.0      8        6
# 1                 4.0                 NaN      5.0      7        7
#
#    Comfortablility  Privacy
# 0                6        6
# 1                3        8
#
# [2 rows x 33 columns]

# %%
df_missing_values = data[['Value Deals Rating','Comedy Gigs Rating','Live Music Rating','Overall Restaurant Rating','Facebook Popularity Quotient','Instagram Popularity Quotient','Resturant Tier','Ambience']]
df_missing_values
# Out:
#       Value Deals Rating  Comedy Gigs Rating  Live Music Rating  \
# 0                    NaN                 NaN                4.0
# 1                    NaN                 4.0                NaN
# 2                    NaN                 NaN                3.0
# 3                    NaN                 NaN                6.0
# 4                    NaN                 2.0                NaN
# ...                  ...                 ...                ...
# 3488                 NaN                 NaN                5.0
# 3489                 NaN                 NaN                4.0
# 3490                 NaN                 NaN                NaN
# 3491                 NaN                 2.0                3.0
# 3492                 NaN                 NaN                1.0
#
#       Overall Restaurant Rating  Facebook Popularity Quotient  \
# 0                          10.0                         84.30
# 1                           9.0                         85.40
# 2                           8.0                         85.00
# 3                           9.0                         85.60
# 4                           6.0                           NaN
# ...                         ...                           ...
# 3488                        9.0                         69.10
# 3489                        NaN                         91.00
# 3490                        8.0                         80.83
# 3491                        7.0                         79.40
# 3492                        NaN                         72.00
#
#       Instagram Popularity Quotient  Resturant Tier  Ambience
# 0                             95.80             2.0       8.0
# 1                             85.00             2.0       5.0
# 2                             68.20             2.0       7.0
# 3                             83.60             1.0       7.0
# 4                             76.80             NaN       NaN
# ...                             ...             ...       ...
# 3488                          62.11             2.0       7.0
# 3489                          96.30             2.0       4.0
# 3490                          86.80             2.0       6.0
# 3491                          86.00             2.0       7.0
# 3492                          67.00             2.0       6.0
#
# [3493 rows x 8 columns]

# %%
df_missing_values.hist(bins = 20, figsize = (15,8))

# adjust the subplots
plt.tight_layout()

# display the plot
plt.show()

# %%
#['Value Deals Rating','Comedy Gigs Rating','Live Music Rating','Overall Restaurant Rating','Facebook Popularity Quotient',
 #'Instagram Popularity Quotient','Resturant Tie','Ambience']
data['Value Deals Rating']=data['Value Deals Rating'].fillna(data['Value Deals Rating'].min())
data['Comedy Gigs Rating']=data['Comedy Gigs Rating'].fillna(data['Comedy Gigs Rating'].min())
data['Live Music Rating']=data['Live Music Rating'].fillna(data['Live Music Rating'].min())
data['Overall Restaurant Rating']=data['Overall Restaurant Rating'].fillna(data['Overall Restaurant Rating'].min())
data['Facebook Popularity Quotient']=data['Facebook Popularity Quotient'].fillna(data['Facebook Popularity Quotient'].min())
data['Instagram Popularity Quotient']=data['Instagram Popularity Quotient'].fillna(data['Instagram Popularity Quotient'].min())
data['Resturant Tier']=data['Resturant Tier'].fillna(data['Resturant Tier'].min())
data['Ambience']=data['Ambience'].fillna(data['Ambience'].min())

# %%
data.shape
# Out:
# (3493, 33)

# %%
data.describe(include = ['object'])
# Out:
#               Cuisine       City Restaurant Location  \
# count            3493       3493                3493
# unique             20        297                   2
# top     tibetan,greek  Bangalore      Near Party Hub
# freq              686        553                2658
#
#        Opening Day of Restaurant   Endorsed By Restaurant Type  \
# count                       3493          3493            3493
# unique                      1778             3               4
# top                   27-12-2009  Not Specific             Bar
# freq                          10          1961            3235
#
#        Restaurant Theme
# count              3493
# unique               34
# top             Arabian
# freq               1373

# %%
data['Restaurant Location'] = pd.get_dummies(data = data['Restaurant Location'], drop_first=True)

# %%
data['Endorsed By'] = pd.get_dummies(data = data['Endorsed By'], drop_first=True)

# %%
data['Restaurant Type'] = pd.get_dummies(data = data['Restaurant Type'], drop_first=True)

# %%
data['Cuisine'] = pd.get_dummies(data = data['Cuisine'], drop_first=True)

# %%
data['Restaurant Theme'] = pd.get_dummies(data = data['Restaurant Theme'], drop_first=True)

# %%
data.head(2)
# Out:
#    Registration Number  Annual Turnover  Cuisine       City  \
# 0                60001         42000000        0  Bangalore
# 1                60002         50000000        0     Indore
#
#    Restaurant Location  Facebook Popularity Quotient  Endorsed By  \
# 0                    0                          84.3            1
# 1                    1                          85.4            0
#
#    Instagram Popularity Quotient  Fire Audit  Liquor License Obtained  ...  \
# 0                           95.8           1                        1  ...
# 1                           85.0           1                        1  ...
#
#    Food Rating  Overall Restaurant Rating  Live Music Rating  \
# 0            7                       10.0                4.0
# 1            8                        9.0                1.0
#
#    Comedy Gigs Rating  Value Deals Rating  Ambience  Lively  Service  \
# 0                 1.0                 1.0       8.0       8        6
# 1                 4.0                 1.0       5.0       7        7
#
#    Comfortablility  Privacy
# 0                6        6
# 1                3        8
#
# [2 rows x 32 columns]

# %%
X=data.drop(columns=['Annual Turnover','City'],axis=0)

# %%
y=data['Annual Turnover']

# %%
X=sm.add_constant(X)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y, random_state=1,test_size = 0.2)

# %%
pred_model=sm.OLS(y_train,x_train).fit()

# %%
print(pred_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Annual Turnover   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     13.65
# Date:                Mon, 10 May 2021   Prob (F-statistic):           5.53e-63
# Time:                        08:23:41   Log-Likelihood:                -50645.
# No. Observations:                2794   AIC:                         1.014e+05
# Df Residuals:                    2763   BIC:                         1.015e+05
# Df Model:                          30
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          2.745e+07   2.19e+07      1.254      0.210   -1.55e+07    7.03e+07
# Registration Number            -413.7434    343.430     -1.205      0.228   -1087.149     259.662
# Cuisine                       -1.108e+06   1.66e+06     -0.667      0.505   -4.37e+06    2.15e+06
# Restaurant Location             2.28e+06   8.37e+05      2.722      0.007    6.38e+05    3.92e+06
# Facebook Popularity Quotient   5.391e+04   3.65e+04      1.476      0.140   -1.77e+04    1.26e+05
# Endorsed By                    1.737e+05   7.69e+05      0.226      0.821   -1.33e+06    1.68e+06
# Instagram Popularity Quotient  1.352e+05   3.64e+04      3.715      0.000    6.38e+04    2.07e+05
# Fire Audit                     1.992e+06   8.47e+05      2.352      0.019    3.31e+05    3.65e+06
# Liquor License Obtained        7.652e+05   3.18e+06      0.240      0.810   -5.48e+06    7.01e+06
# Situated in a Multi Complex   -2.447e+06   8.79e+05     -2.784      0.005   -4.17e+06   -7.24e+05
# Dedicated Parking              1.669e+06   8.67e+05      1.925      0.054   -3.14e+04    3.37e+06
# Open Sitting Available         4.701e+05   8.64e+05      0.544      0.587   -1.22e+06    2.17e+06
# Resturant Tier                -7.872e+06   1.31e+06     -6.020      0.000   -1.04e+07   -5.31e+06
# Restaurant Type                9.178e+06   1.83e+07      0.501      0.616   -2.67e+07    4.51e+07
# Restaurant Theme              -7.126e+06   1.82e+07     -0.391      0.696   -4.28e+07    2.86e+07
# Restaurant Zomato Rating       1.187e+06   4.84e+05      2.454      0.014    2.38e+05    2.14e+06
# Restaurant City Tier          -1.212e+06   7.69e+05     -1.577      0.115   -2.72e+06    2.95e+05
# Order Wait Time                9.143e+04   1.21e+05      0.755      0.450   -1.46e+05    3.29e+05
# Staff Responsivness            1.257e+06   3.75e+05      3.355      0.001    5.22e+05    1.99e+06
# Value for Money                5.799e+05   4.68e+05      1.239      0.216   -3.38e+05     1.5e+06
# Hygiene Rating                 1.378e+06   3.38e+05      4.075      0.000    7.15e+05    2.04e+06
# Food Rating                    4.502e+05      2e+05      2.247      0.025    5.73e+04    8.43e+05
# Overall Restaurant Rating      6.605e+05   2.68e+05      2.468      0.014    1.36e+05    1.19e+06
# Live Music Rating              1.105e+06   2.71e+05      4.074      0.000    5.73e+05    1.64e+06
# Comedy Gigs Rating            -4.023e+05   3.91e+05     -1.029      0.304   -1.17e+06    3.65e+05
# Value Deals Rating            -1.915e+06   3.06e+05     -6.255      0.000   -2.52e+06   -1.31e+06
# Ambience                      -4.749e+05   1.96e+05     -2.422      0.016   -8.59e+05   -9.04e+04
# Lively                         5.155e+05   2.51e+05      2.053      0.040    2.31e+04    1.01e+06
# Service                        2.925e+04   2.12e+05      0.138      0.891   -3.87e+05    4.46e+05
# Comfortablility               -2.165e+05   1.87e+05     -1.156      0.248   -5.84e+05    1.51e+05
# Privacy                       -2.341e+05   2.24e+05     -1.044      0.297   -6.74e+05    2.06e+05
# ==============================================================================
# Omnibus:                     3280.783   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           581959.026
# Skew:                           5.911   Prob(JB):                         0.00
# Kurtosis:                      72.708   Cond. No.                     3.94e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.94e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
linreg=LinearRegression()

# %%
MLR_model = linreg.fit(x_train, y_train)

# %%
train_pred = MLR_model.predict(x_train)

# %%
mse_train = mean_squared_error(y_train, train_pred)
rmse_train = round(np.sqrt(mse_train), 4)
print("Root Mean Squared Error (RMSE) on training set: ", rmse_train)
# Out:
# Root Mean Squared Error (RMSE) on training set:  18029247.5803

# %%
#Ridge Regression
ridge = Ridge(alpha = 5.5)
ridge_model = ridge.fit(x_train, y_train)

# %%
#For Train Data
train_pred = ridge_model.predict(x_train)
mse_train = mean_squared_error(y_train, train_pred)
rmse_train = round(np.sqrt(mse_train), 4)
print("Root Mean Squared Error (RMSE) on training set: ", rmse_train)
#For Test Data
test_pred = ridge_model.predict(x_test)
mse_test = mean_squared_error(y_test, test_pred)
rmse_test = round(np.sqrt(mse_test), 4)
print("Root Mean Squared Error (RMSE) on test set: ", rmse_test)
# Out:
# Root Mean Squared Error (RMSE) on training set:  18030301.6862
# Root Mean Squared Error (RMSE) on test set:  27962550.2541
