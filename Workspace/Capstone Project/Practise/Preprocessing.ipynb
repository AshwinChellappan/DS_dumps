# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import math

# %%
df=pd.read_csv('data.csv')

# %%
df.shape
# Out:
# (6819, 96)

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
Q1 = df.quantile(0.01)
Q3 = df.quantile(0.99)
IQR = Q3 - Q1
df = df[~((df < (Q1-6*IQR)) | (df > (Q3 + 6*IQR))).any(axis = 1)]

# %%
df.shape
# Out:
# (6552, 96)

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6369
# 1     183
# Name: Bankrupt?, dtype: int64

# %%
#df_scale=df.drop(columns='Bankrupt?')

# %%
minmax=MinMaxScaler()

# %%
df_scaled=minmax.fit_transform(df)

# %%
df_scaled=pd.DataFrame(data=df_scaled,columns=df.columns)

# %%
df_scaled.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0        1.0                                           0.381454
# 1        1.0                                           0.411561
# 2        1.0                                           0.478649
# 3        1.0                                           0.400070
# 4        0.0                                           0.402378
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.420377
# 1                                 0.447439
# 2                                 0.535214
# 3                                 0.411100
# 4                                 0.441840
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.457733
# 2                                           0.522298
# 3                                           0.419134
# ...

# %%
df_scaled.columns = df_scaled.columns.str.strip()
df_scaled.columns = df_scaled.columns.str.replace(" " ,"_")
df_scaled.rename(columns = {'Bankrupt?' :'Bankrupt' },inplace=True)

# %%
df_scaled.shape
# Out:
# (6552, 96)

# %%
df_scaled.head()
# Out:
#    Bankrupt  ROA(C)_before_interest_and_depreciation_before_interest  \
# 0       1.0                                           0.381454
# 1       1.0                                           0.411561
# 2       1.0                                           0.478649
# 3       1.0                                           0.400070
# 4       0.0                                           0.402378
#
#    ROA(A)_before_interest_and_%_after_tax  \
# 0                                0.420377
# 1                                0.447439
# 2                                0.535214
# 3                                0.411100
# 4                                0.441840
#
#    ROA(B)_before_interest_and_depreciation_after_tax  Operating_Gross_Margin  \
# 0                                           0.405750                0.709830
# 1                                           0.457733                0.628209
# 2                                           0.522298                0.697649
# ...

# %%
df_scaled['Bankrupt']=df_scaled['Bankrupt'].astype('int64')

# %%
df_scaled.head()
# Out:
#    Bankrupt  ROA(C)_before_interest_and_depreciation_before_interest  \
# 0         1                                           0.381454
# 1         1                                           0.411561
# 2         1                                           0.478649
# 3         1                                           0.400070
# 4         0                                           0.402378
#
#    ROA(A)_before_interest_and_%_after_tax  \
# 0                                0.420377
# 1                                0.447439
# 2                                0.535214
# 3                                0.411100
# 4                                0.441840
#
#    ROA(B)_before_interest_and_depreciation_after_tax  Operating_Gross_Margin  \
# 0                                           0.405750                0.709830
# 1                                           0.457733                0.628209
# 2                                           0.522298                0.697649
# ...

# %%
df_scaled['Bankrupt'].value_counts()
# Out:
# 0    6369
# 1     183
# Name: Bankrupt, dtype: int64

# %%
df_scaled.to_csv("datapreprocessed.csv")
