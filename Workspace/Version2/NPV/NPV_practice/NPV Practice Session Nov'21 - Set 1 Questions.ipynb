# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Import the necessary libraries: </b> </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <body>
# <h2 style="background-color:#0067a7; color:#FFFFFF"align="center">COVID Dataset</h2>
# </body>

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 1: Create a dataframe using the below data </b> </p>
#
# 	State	                        Active_Cases 	 Recovered 	 Deceased
#     Andaman and Nicobar Islands	    268 	         3,202 	     51
#     Andhra Pradesh	                 95,733 	      457,008 	   4,846
#     Arunachal Pradesh	              1,712 	       4,253 	     10
#     Assam	                          29,133 	      110,885 	   453
#     Bihar	                          14,396           141,499 	   808

# %%
df=pd.read_csv('Covid_data.csv')

# %%
df.head()
# Out:
#    S. No.                        State  Active Cases   Recovered   deceased
# 0       1  Andaman and Nicobar Islands           268       3,202         51
# 1       2               Andhra Pradesh        95,733     457,008      4,846
# 2       3            Arunachal Pradesh         1,712       4,253         10
# 3       4                        Assam        29,133     110,885        453
# 4       5                        Bihar        14,396     141,499        808

# %%
df = pd.DataFrame({'State':['Andaman and Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar'],'Active_Cases':[268, 95733, 1712, 29133,14396], 'Recovered':[3202, 457008, 4253, 110885,141499], 'Deceased':[51,4846, 10, 453, 808]})

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 2: Print the summary of the dataframe </b> </p>

# %%
df.describe()
# Out:
#           S. No.
# count  35.000000
# mean   18.000000
# std    10.246951
# min     1.000000
# 25%     9.500000
# 50%    18.000000
# 75%    26.500000
# max    35.000000

# %%
# Out:
#                          State  Active_Cases  Recovered  Deceased
# 0  Andaman and Nicobar Islands           268       3202        51
# 1               Andhra Pradesh         95733     457008      4846
# 2            Arunachal Pradesh          1712       4253        10
# 3                        Assam         29133     110885       453
# 4                        Bihar         14396     141499       808

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 3: Display the top 5 records</b> </p>

# %%
df.head()
# Out:
#                          State  Active_Cases  Recovered  Deceased
# 0  Andaman and Nicobar Islands           268       3202        51
# 1               Andhra Pradesh         95733     457008      4846
# 2            Arunachal Pradesh          1712       4253        10
# 3                        Assam         29133     110885       453
# 4                        Bihar         14396     141499       808

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 4: Get the covid case details of Assam </b> </p>

# %%
df[df['State']=='Assam']
# Out:
#    State  Active_Cases  Recovered  Deceased
# 3  Assam         29133     110885       453

# %%
df.loc[3]
# Out:
# State            Assam
# Active_Cases     29133
# Recovered       110885
# Deceased           453
# Name: 3, dtype: object

# %%
# Out:
#    Active_Cases  Deceased
# 3         29133       453

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 5: Get the total active cases and deceased cases in Assam </b> </p>

# %%
df[df['State']=='Assam'][['Active_Cases','Deceased']]
# Out:
#    Active_Cases  Deceased
# 3         29133       453

# %%
df[['Active_Cases','Deceased']][3:4]
# Out:
#    Active_Cases  Deceased
# 3         29133       453

# %%
df.iloc[3,[0,1,3]]
# Out:
# State           Assam
# Active_Cases    29133
# Deceased          453
# Name: 3, dtype: object

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 6: Get the total active cases and recovered cases in Andhra Pradesh & Bihar  </b> </p>

# %%
df[(df['State'] ==('Andhra Pradesh')) | ((df['State'] ==('Bihar'))) ][['Active_Cases','Recovered']]
# Out:
#    Active_Cases  Recovered
# 1         95733     457008
# 4         14396     141499

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 7: Add the below record to the existing dataframe </b> </p>

# %% [raw]
# Mizoram      591         823         0
# Tamil Nadu	 47110 	     441649 	 8307

# %%
#use append and concatenate
df = pd.DataFrame({'State':['Mizoram', 'Tamil Nadu'],'Active_Cases':[591, 47110], 'Recovered':[823,441649], 'Deceased':[0, 8307]})

# %%
df.loc[5]=['Mizoram',591,823,0]
df.loc[6]=['Tamil Nadu',47110,441649,8307]

# %%
df.loc[5] = ['Mizoram', 591, 823, 0]
df.loc[6] = ['Tamil Nadu', 47110, 441649, 8307 ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-38c650ac9a67> in <module>
# ----> 1 df.loc[5] = ['Mizoram', 591, 823, 0]
#       2 df.loc[6] = ['Tamil Nadu', 47110, 441649, 8307 ]
#
# C:\Ashwin\Learning\Datascience\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# C:\Ashwin\Learning\Datascience\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# C:\Ashwin\Learning\Datascience\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1709
#    1710             else:
# -> 1711                 raise ValueError(
#    1712                     "Must have equal len keys and value "
#    1713                     "when setting with an iterable"
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 8: Display the whole dataframe, with recovery rate in descending order</b> </p>

# %%
df.head()
# Out:
#    S. No.                        State  Active Cases   Recovered   deceased
# 0       1  Andaman and Nicobar Islands           268       3,202         51
# 1       2               Andhra Pradesh        95,733     457,008      4,846
# 2       3            Arunachal Pradesh         1,712       4,253         10
# 3       4                        Assam        29,133     110,885        453
# 4       5                        Bihar        14,396     141,499        808

# %%
df.sort_values(by='State',ascending=0)
# Out:
#     S. No.                                     State  Active Cases   \
# 34      35                               West Bengal        23,521
# 32      33                               Uttarakhand         9,781
# 33      34                             Uttar Pradesh        67,955
# 31      32                                   Tripura         7,584
# 30      31                                 Telengana        31,607
# 29      30                                Tamil Nadu        47,110
# 28      29                                    Sikkim           541
# 27      28                                 Rajasthan        16,582
# 26      27                                    Punjab        19,384
# 25      26                                Puducherry         4,847
# 24      25                                    Odisha        30,999
# 23      24                                  Nagaland         1,215
# 22      23                                   Mizoram           591
# 21      22                                 Meghalaya         1,570
# 20      21                                   Manipur         1,584
# 19      20                               Maharashtra       280,138
# 18      19                            Madhya Pradesh        19,840
# 17      18                                    Ladakh           841
# 16      17                                    Kerala        28,870
# 15      16                                 Karnataka        97,834
# 14      15                                 Jharkhand        14,844
# 13      14                         Jammu and Kashmir        16,261
# 12      13                          Himachal Pradesh         3,194
# 11      12                                   Haryana        19,446
# 10      11                                   Gujarat        16,301
# 9       10                                       Goa         5,323
# 8        9                                     Delhi        28,059
# 7        8  Dadra and Nagar Haveli and Daman and Diu           279
# 6        7                              Chhattisgarh        33,246
# 5        6                                Chandigarh         2,586
# 4        5                                     Bihar        14,396
# 3        4                                     Assam        29,133
# 2        3                         Arunachal Pradesh         1,712
# 1        2                            Andhra Pradesh        95,733
# 0        1               Andaman and Nicobar Islands           268
#
#     Recovered   deceased
# 34    172,085      3,887
# 32     20,153        402
# 33    233,527      4,349
# 31     11,132        194
# 30    124,528        961
# 29    441,649      8,307
# 28      1,503         11
# 27     82,902      1,221
# 26     55,385      2,288
# 25     14,228        370
# 24    115,279        616
# 23      3,839         10
# 22        823        -
# 21      2,020         25
# 20      6,102         45
# 19    728,512     29,115
# 18     64,398      1,728
# 17      2,414         39
# 16     75,844        425
# 15    344,556      7,161
# 14     45,074        542
# 13     35,285        864
# 12      5,962         73
# 11     70,713        956
# 10     92,678      3,195
# 9      18,576        286
# 8     181,295      4,715
# 7       2,444          2
# 6      27,978        539
# 5       4,864         92
# 4     141,499        808
# 3     110,885        453
# 2       4,253         10
# 1     457,008      4,846
# 0       3,202         51

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 9: Rank the active cases in descending order and add the same in the existing dataframe. Display the records with the lowest rank coming first </b> </p>

# %%
df.head()
# Out:
#    S. No.                        State  Active Cases   Recovered   deceased
# 0       1  Andaman and Nicobar Islands           268       3,202         51
# 1       2               Andhra Pradesh        95,733     457,008      4,846
# 2       3            Arunachal Pradesh         1,712       4,253         10
# 3       4                        Assam        29,133     110,885        453
# 4       5                        Bihar        14,396     141,499        808

# %%
df['Active_Cases_rank']=df['Active Cases'].rank(ascending=False)
df.sort_values(by='Active_Cases_rank')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Ashwin\Learning\Datascience\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Active Cases'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-caf23d59d5be> in <module>
# ----> 1 df['Active_Cases_rank']=df['Active Cases'].rank(ascending=False)
#       2 df.sort_values(by='Active_Cases_rank')
#
# C:\Ashwin\Learning\Datascience\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\Ashwin\Learning\Datascience\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Active Cases'

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 10: Create a dataframe with below mentioned details and rank the scores based on min, max and dense methods </b> </p>

# %%
stu_score = pd.DataFrame({'Student' : ['Tom', 'Jack', 'Liya',  'Jess', 'Ben'], 
                        'Scores' : [90, 60, 70, 60, 70]})
stu_score
# Out:
#   Student  Scores
# 0     Tom      90
# 1    Jack      60
# 2    Liya      70
# 3    Jess      60
# 4     Ben      70

# %%
stu_score.rank(method='min')
# Out:
#    Student  Scores
# 0      5.0     5.0
# 1      2.0     1.0
# 2      4.0     3.0
# 3      3.0     1.0
# 4      1.0     3.0

# %%
stu_score['rnk']=stu_score['Scores'].rank(ascending=False)

# %%
stu_score
# Out:
#   Student  Scores  rnk
# 0     Tom      90  1.0
# 1    Jack      60  4.5
# 2    Liya      70  2.5
# 3    Jess      60  4.5
# 4     Ben      70  2.5

# %%
stu_score['rnk_min']=stu_score['Scores'].rank(ascending=False,method='min')
stu_score['rnk_max']=stu_score['Scores'].rank(ascending=False,method='max')
stu_score['rnk_dense']=stu_score['Scores'].rank(ascending=False,method='dense')

# %%
stu_score
# Out:
#   Student  Scores  rnk  rnk_min  rnk_max  rnk_dense
# 0     Tom      90  1.0      1.0      1.0        1.0
# 1    Jack      60  4.5      4.0      5.0        3.0
# 2    Liya      70  2.5      2.0      3.0        2.0
# 3    Jess      60  4.5      4.0      5.0        3.0
# 4     Ben      70  2.5      2.0      3.0        2.0

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 11: Set the state column as index to the dataframe </b> </p>

# %%
df=df.set_index('State')

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 12: Read the covid_data csv file</b> </p>

# %%
covid=pd.read_csv('Covid_data.csv')

# %%
covid.head()
# Out:
#    S. No.                        State  Active Cases   Recovered   deceased
# 0       1  Andaman and Nicobar Islands           268       3,202         51
# 1       2               Andhra Pradesh        95,733     457,008      4,846
# 2       3            Arunachal Pradesh         1,712       4,253         10
# 3       4                        Assam        29,133     110,885        453
# 4       5                        Bihar        14,396     141,499        808

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 13: Drop the S.No. column </b> </p>

# %%
df1=covid.drop('S. No.',axis=1)

# %%
df1.head()
# Out:
#                          State  Active Cases   Recovered   deceased
# 0  Andaman and Nicobar Islands           268       3,202         51
# 1               Andhra Pradesh        95,733     457,008      4,846
# 2            Arunachal Pradesh         1,712       4,253         10
# 3                        Assam        29,133     110,885        453
# 4                        Bihar        14,396     141,499        808

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 14: Remove the blank spaces present in the column names </b> </p>

# %%
df1['State']=df1['State'].str.replace(' ','')

# %%
df1.head()
# Out:
#                       State  Active Cases   Recovered   deceased
# 0  AndamanandNicobarIslands           268       3,202         51
# 1             AndhraPradesh        95,733     457,008      4,846
# 2          ArunachalPradesh         1,712       4,253         10
# 3                     Assam        29,133     110,885        453
# 4                     Bihar        14,396     141,499        808

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 15: Remove the , symbol present in the records </b> </p>

# %%
df1[' Recovered ']=df1[' Recovered '].str.replace(',','')

# %%
df1[' Active Cases  ']=df1[' Active Cases '].str.replace(',','')

# %%
df1[' deceased ']=df1[' deceased '].str.replace(',','')

# %%
df1.head()
# Out:
#                       State  Active Cases   Recovered   deceased   \
# 0  AndamanandNicobarIslands           268        3202         51
# 1             AndhraPradesh        95,733      457008       4846
# 2          ArunachalPradesh         1,712        4253         10
# 3                     Assam        29,133      110885        453
# 4                     Bihar        14,396      141499        808
#
#    Active Cases
# 0            268
# 1          95733
# 2           1712
# 3          29133
# 4          14396

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 16: Replace the string '-' present in the deceased column with 0  </b> </p>

# %%
df1[' deceased ']=df1[' deceased '].str.replace('-','0')

# %%
df1[' deceased '].value_counts()
# Out:
#  10         2
#  4,846      1
#  2          1
#  7,161      1
#  4,715      1
#  286        1
#  0          1
#  453        1
#  3,195      1
#  8,307      1
#  370        1
#  864        1
#  45         1
#  808        1
#  39         1
#  25         1
#  2,288      1
#  542        1
#  4,349      1
#  956        1
#  1,221      1
#  1,728      1
#  194        1
#  961        1
#  73         1
#  425        1
#  402        1
#  539        1
#  51         1
#  3,887      1
#  616        1
#  92         1
#  29,115     1
#  11         1
# Name:  deceased , dtype: int64

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 17: Check the data information, convert the column with values in numbers to int data type </b> </p>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           35 non-null     object
#  1    Active Cases   35 non-null     object
#  2    Recovered      35 non-null     object
#  3    deceased       35 non-null     object
# dtypes: object(4)
# memory usage: 1.2+ KB

# %%
df1[' Recovered ']=df1[' Recovered '].astype(int)
df1[' deceased ']=df1[' deceased '].astype(int)
df1[' Active Cases ']=df1[' Active Cases  '].astype(int)

# %%
df1=df1.astype({' Active Cases ','int':' Active Cases ','int'})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            35 non-null     object
#  1    Active Cases    35 non-null     int32
#  2    Recovered       35 non-null     int32
#  3    deceased        35 non-null     int32
#  4    Active Cases    35 non-null     object
# dtypes: int32(3), object(2)
# memory usage: 1.1+ KB

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 18: Provide the summary statistics </b> </p>

# %%
df1.describe()
# Out:
#         Active Cases      Recovered      deceased
# count       35.000000      35.000000     35.000000
# mean     27805.000000  105788.428571   2245.314286
# std      50203.316039  160744.726694   5134.089213
# min        268.000000     823.000000      0.000000
# 25%       2149.000000    5413.000000     62.000000
# 50%      16261.000000   45074.000000    539.000000
# 75%      29001.500000  119903.500000   2008.000000
# max     280138.000000  728512.000000  29115.000000

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 19: Find out the states whose recovery rate is greater than the average recovery rate </b> </p>

# %%
df1.head()
# Out:
#                       State   Active Cases    Recovered    deceased   \
# 0  AndamanandNicobarIslands             268         3202          51
# 1             AndhraPradesh           95733       457008        4846
# 2          ArunachalPradesh            1712         4253          10
# 3                     Assam           29133       110885         453
# 4                     Bihar           14396       141499         808
#
#    Active Cases
# 0            268
# 1          95733
# 2           1712
# 3          29133
# 4          14396

# %%
df1[df1[' Recovered ']>df1[' Recovered '].mean()]
# Out:
#             State   Active Cases    Recovered    deceased   Active Cases
# 1   AndhraPradesh           95733       457008        4846          95733
# 3           Assam           29133       110885         453          29133
# 4           Bihar           14396       141499         808          14396
# 8           Delhi           28059       181295        4715          28059
# 15      Karnataka           97834       344556        7161          97834
# 19    Maharashtra          280138       728512       29115         280138
# 24         Odisha           30999       115279         616          30999
# 29      TamilNadu           47110       441649        8307          47110
# 30      Telengana           31607       124528         961          31607
# 33   UttarPradesh           67955       233527        4349          67955
# 34     WestBengal           23521       172085        3887          23521

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 20: Find out the states whose deceased count is less than 500 and the active cases is less than 20000 </b> </p>

# %%
df1[(df1[' deceased ']<500) & (df1[' Active Cases ']<20000)][['State']]
# Out:
#                                 State
# 0            AndamanandNicobarIslands
# 2                    ArunachalPradesh
# 5                          Chandigarh
# 7   DadraandNagarHaveliandDamanandDiu
# 9                                 Goa
# 12                    HimachalPradesh
# 17                             Ladakh
# 20                            Manipur
# 21                          Meghalaya
# 22                            Mizoram
# 23                           Nagaland
# 25                         Puducherry
# 28                             Sikkim
# 31                            Tripura
# 32                        Uttarakhand

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 21: Load the emp1, emp2 and dept datasets </b> </p>

# %%
e1=pd.read_csv('Emp_data_1.csv')
e2=pd.read_csv('Emp_data_2.csv')
de=pd.read_csv('Dept_data.csv')

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 21: Concatenate the employee1 and 2 datasets </b> </p>

# %%
e1.head()
# Out:
#    Emp_id Emp_Name  Salary  manager_id  department_id
# 0       1      Tom    5000         101             20
# 1       2     Jake   40000         100             10
# 2       3      Ben    4500         100             10
# 3       4     Alex    2500         102             30
# 4       5     Ryan    4350         103             50

# %%
e2.head()
# Out:
#    Emp_id Emp_Name   Salary  manager_id  department_id
# 0       8    Maria  14000.0       103.0           50.0
# 1       9    Laura  22000.0       101.0           20.0
# 2      10   Emelia   9000.0       102.0           30.0
# 3      11    Buddy      NaN         NaN            NaN
# 4      12     Jess  21000.0       101.0           20.0

# %%
c1=pd.concat([e1,e2],axis=0,ignore_index=True)

# %%
c1
# Out:
#     Emp_id Emp_Name   Salary  manager_id  department_id
# 0        1      Tom   5000.0       101.0           20.0
# 1        2     Jake  40000.0       100.0           10.0
# 2        3      Ben   4500.0       100.0           10.0
# 3        4     Alex   2500.0       102.0           30.0
# 4        5     Ryan   4350.0       103.0           50.0
# 5        6     Liya   5500.0       104.0           40.0
# 6        7     Jane  20000.0       103.0           50.0
# 7        8    Maria  14000.0       103.0           50.0
# 8        9    Laura  22000.0       101.0           20.0
# 9       10   Emelia   9000.0       102.0           30.0
# 10      11    Buddy      NaN         NaN            NaN
# 11      12     Jess  21000.0       101.0           20.0

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 22: Merge the employee and department table, on column department id. Ensure that none of the record is missed out </b> </p>

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 23: Join the dept and emp table on dept id, display only the matching records </b> </p>

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 24: Merge the emp and dept table based on dept id. Display all the records in employee table and the matching records in department table </b> </p>

# %% [markdown]
# <p style="background-color:#b5e7a0;font-size:18px;color:#4040a1" size="4"><b> Exercise 25: Merge the emp and dept table based on dept id. Display all the records in department table and the matching records in employee table </b> </p>
