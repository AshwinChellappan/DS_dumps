# %% [markdown]
# ### Lest check All Graphs

# %% [markdown]
# 1.DISTRIBUTION
#
# 2.CORRELATION
#
# 3.RANKING
#
# 4.GROUPED PLOT

# %% [markdown]
# # 1.DISTRIBUTION

# %% [markdown]
# A. VIOLIN
#
# B. DENSITY
#
# C. BOXPLOT
#
# D. HISTOGRAM

# %% [markdown]
# ### A. VIOLIN

# %% [markdown]
# * Violinplots allow to visualize the distribution of a numeric variable for one or several groups. It is really close from a boxplot, but allows a deeper understanding of the density. Violins are
#
# * particularly adapted when the amount of data is huge and showing individual observations gets impossible. Seaborn is particularly adapted to realize them through its violin function.

# %%
# library & dataset
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')
 
# Make boxplot for one group only
sns.violinplot( y=df["sepal_length"],color="#85E0E4")

# %% [markdown]
# #### Observation: Violin plots have many of the same summary statistics as box plots
# 1. the white dot represents the median
# 2. the thick gray bar in the center represents the interquartile range
# 3. the thin gray line represents the rest of the distribution, except for points that are determined to be “outliers” using a 4. method that is a function of the interquartile range.

# %% [markdown]
# ### B. DENSITY

# %% [markdown]
# * A density plot shows the distribution of a numerical variable. It takes only set of numeric values as input. It is really close to a histogram. Since it is a really common dataviz technique,

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Make default density plot
sns.kdeplot(df['sepal_width'],color="#AA2FF2")
#sns.plt.show()

# %% [markdown]
# #### Observation:
# 1. Using a smaller bandwidth shows the heaping at 3.0.
# 2. With seaborn, a  density plot is made using the kdeplot function.
# 3. As input, density plot need only one numerical variable.

# %% [markdown]
# ## C. BOXPLOT

# %% [markdown]
# * Boxplot is probably one of the most common type of graphic. It gives a nice summary of one or several numeric variables. The line that divides the box into 2 parts represents the median of the data.
# * The end of the box shows the upper and lower quartiles. The extreme lines shows the highest and lowest value excluding outliers.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
sns.boxplot( x=df["species"], y=df["sepal_length"],color="#85E0E4" )

# %% [markdown]
# ### Observation:
#
# 1. The following box plot. Each horizontal line starting from bottom will show the minimum, lower quartile, median, upper quartile and maximum value of Sepal.Length.
# 2. If you look at the bottom of third box plot you will find an outlier.
# 3. Grouped boxplot are used when you have a numerical variable, several groups and subgroups.

# %% [markdown]
# ### D. HISTOGRAM

# %% [markdown]
# * An histogram is an accurate graphical representation of the distribution of numerical data. It takes as input one numerical variable only. The variable is cut into several bins,

# %%
# Import library and dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Control the number of bins
sns.distplot( df["sepal_length"], bins=20,color="#d61323" )
#sns.plt.show()

# %% [markdown]
# Observation:
#     1. That line is Density line.
#     2. Always in Histogram we use bin size and in this plot we can see sepal_length distribution.

# %% [markdown]
# ## 2. CORRELATION

# %% [markdown]
#     1. Scatterplot
#     2. Connected Scatter plot
#     3. Bubble plot
#     4. Heatmap
#     5. 2D density plot
#     6. Correlogram

# %% [markdown]
# ### Scatterplot

# %% [markdown]
# 1. A Scatterplot displays 2 sets of data on 2 dimensions. Each dot represents an observation. The position on the X (horizontal) and Y (vertical) axis represents the values of the 2

# %%
# library & dataset
import seaborn as sns

import matplotlib.pyplot as plt
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# Observation:
# 1. Plot showing categorical variable with group.
# 2. The colors showing the different group.

# %% [markdown]
# ### Scatterplot with regression line:

# %%
# library &amp; dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# plot
sns.regplot(x=df["sepal_length"], y=df["sepal_width"], line_kws={"color":"r","alpha":0.7,"lw":5})

# %% [markdown]
# Observation:
#     1. Here horizontal line is sepal_width Vs sepal_length have corelation is Zero.

# %% [markdown]
# ### Connected Scatter plot

# %% [markdown]
# A connected scatterplot is really close from a scatterplot, except that dots are linked one to each other with lines.

# %%
# library and dataset
import seaborn as sns
# Create data
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101), 'z': (np.random.randn(100)*15+range(1,101))*2 })
plt.plot( 'x', 'y', data=df, marker='o', color='mediumvioletred')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data; using as data.  Either rename the entry in data or use three arguments to plot.
#   """

# %% [markdown]
# Observation:
#     1. In this plot we can see were increasing and Decreasing trend also.

# %% [markdown]
# ## Bubble plot

# %%
# create data
x = np.random.rand(15)
y = x+np.random.rand(15)
z = x+np.random.rand(15)
z=z*z
 
# Change color with c and alpha. I map the color to the X axis value.
plt.scatter(x, y, s=z*2000, c=x, cmap="Blues", alpha=0.3, edgecolors="#b20ddb", linewidth=2)
 
# Add titles (main and on axis)
plt.xlabel("the X axis")
plt.ylabel("the Y axis")
plt.title("bubble plot")
# Out:
# Text(0.5, 1.0, 'bubble plot')

# %% [markdown]
# Observation:
#     1. A bubble plot is a scatterplot with a third dimension.
#     2. The size of the markers is one of Observation

# %% [markdown]
# ## HEATMAP

# %% [markdown]
# 1. A heat map uses a warm-to-cool color spectrum to show you your site analytics, namely which parts of a page receive the most attention.

# %%
# Create a dataset (fake)
df = pd.DataFrame(np.random.random((100,5)), columns=["a","b","c","d","e"])
 
# Calculate correlation between each pair of variable
corr_matrix=df.corr()
 
# plot it
sns.heatmap(corr_matrix)

# %% [markdown]
# Observation:
#     1. The white color means correlation is positive,
#     2. The dark color is no corelation.

# %% [markdown]
# ## 2D DENSITY PLOT

# %% [markdown]
# A 2D density plot or  2D histogram we can called. It shows the distribution of values in a data across the range of two quantitative variables.

# %%
from scipy.stats import kde
 
# Create data: 100 points
data = np.random.multivariate_normal([0, 0], [[1, 0.5], [0.5, 3]], 100)
x, y = data.T
 
# Create a figure with 6 plot areas
fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(21, 5))
 
# Everything sarts with a Scatterplot
axes[0].set_title('Scatterplot')
axes[0].plot(x, y, 'ro')

 # Thus we can cut the plotting window in several hexbins
nbins = 20
axes[1].set_title('Hexbin')
axes[1].hexbin(x, y, gridsize=nbins)
 
# 2D Histogram
axes[2].set_title('2D Histogram')
axes[2].hist2d(x, y, bins=nbins)
 
# Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
k = kde.gaussian_kde(data.T)
xi, yi = np.mgrid[x.min():x.max():nbins*1j, y.min():y.max():nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

# %% [markdown]
# Observation:
#     1. Here we can see stages of how to view the data.

# %% [markdown]
# ### Correlogram

# %% [markdown]
# A correlogram or correlation matrix allows to analyse the relationship between each pair of numerical variables of a matrix.

# %%
# library & dataset
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')
 
# with regression
sns.pairplot(df, kind="reg")
plt.show()

# %% [markdown]
# Observation:
#     1. Here we can Observe regression line with correlation
#     2. petal_width Vs Sepal_width have a negative correlation.

# %% [markdown]
# # RANKING

# %% [markdown]
#     1. Barplot
#     2. Boxplot
#     3. Parallel plot
#     4. Lollipop plot
#     5. Wordcloud
#     6. Spider

# %% [markdown]
# ## Barplot

# %%
# Make a fake dataset:
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars)
# Out:
# ([<matplotlib.axis.XTick at 0x237c84e4ba8>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# Observation:
#     1. The bar plot showing the group of data.
#     2. We use Categorical data like countplot.

# %% [markdown]
# ### PARALLEL PLOT

# %% [markdown]
# Parallel plot or Parallel Coordinates we can also call. Plots allow to compare the feature of several individual observations on a set of numerical variables.

# %%
data = sns.load_dataset('iris')
# Make the plot
pd.plotting.parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
plt.show()

# %% [markdown]
# Observation:
#     1. here we can see trend kind of graph.

# %% [markdown]
# ## Lollipop plot

# %%
# create data
x=range(1,41)
values=np.random.uniform(size=40)
 
# stem function: first way
plt.stem(x, values)
plt.ylim(0, 1.2)
plt.stem(values)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# Observation:
#
#     1: using the stem() function or vline() function.

# %% [markdown]
# ## Wordcloud

# %% [markdown]
# A Wordcloud (or Tag cloud) we camn also call. And visual representation of text data. It displays a list of words, the importance of each beeing shown with font size or color.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
 
# Create a list of word
text=("SQL Python ML Matplotlib Matplotlib Seaborn Great Learning Plot Violin Chart Pandas Great Learning Datascience Great Learning Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Great Learning Scatter Barplot Barplot Great Learning Boxplot Violinplot Great Learning Treemap Great Learning Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")
 
# Create the wordcloud object
wordcloud = WordCloud(width=880, height=580, margin=0).generate(text)
 
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Observation:
#     1. We can see Great Learning is the most repeated word in text.

# %% [markdown]
# ## Spider Plot

# %%
# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({'group': ['A','B','C','D'],'var1': [38, 1.5, 30, 4],'var2': [29, 10, 9, 34],'var3': [8, 39, 23, 24],
                   'var4': [7, 31, 33, 14],'var5': [28, 15, 32, 14]})
 
# number of variable
categories=list(df)[1:]
N = len(categories)
 
# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='red', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="green", size=10)
plt.ylim(0,40)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'd', alpha=0.5)

# %% [markdown]
# Observation:
# 1. A radar chart displays the value of several numerical variables for one or several entities.
# 2. Here is an we can see a simple one, displaying the values of 5 variables for only one individual.

# %% [markdown]
# ## Grouped Data

# %% [markdown]
#     1. Stacked barplot
#     2. Tree plot
#     3. Venn diagram
#     4. Doughnut plot
#     5. Pie plot
#     6. Tree diagram

# %% [markdown]
# ## Stacked barplot

# %% [markdown]
# The barplot() function takes a Contingency table as input. You can either create the table first and then pass it to the  barplot() function or you can create the table directly in the barplot() function.

# %%
from matplotlib import rc

# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = [12, 28, 1, 8, 22]
bars2 = [28, 7, 16, 4, 10]
bars3 = [25, 3, 23, 25, 17]
 
# Heights of bars1 + bars2
bars = np.add(bars1, bars2).tolist()
 
# The position bars on the x-axis
r = [0,1,2,3,4]
 
# Names of group and bar width
names = ['A','B','C','D','E']
barWidth = 1
plt.bar(r, bars1, color='#7f6d5f', edgecolor='#cbed90', width=barWidth)
# Create green bars (middle)
plt.bar(r, bars2, bottom=bars1, color='#97efbb', edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, bars3, bottom=bars, color='#dd94ef', edgecolor='white', width=barWidth)
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("group")
 
# Show graphic
plt.show()

# %% [markdown]
# ## Tree plot

# %%
import squarify    
 
# create  2 lists
squarify.plot(sizes=[13,22,35,5], label=["group A", "group B", "group C", "group D"], alpha=.7 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Venn diagram

# %%
# Import the library
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
 
# Make the diagram
venn3(subsets = (10, 8, 22, 6,9,4,2))
plt.show()

# %% [markdown]
# ## Doughnut plot

# %%
names='groupA', 'groupB', 'groupC', 'groupD',
size=[12,11,3,30]
 
# Create a circle 
my_circle=plt.Circle( (0,0), 0.7, color='white')
# Give color names
plt.pie(size, labels=names, colors=['pink','green','blue','skyblue'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# ## Pie plot

# %%
df = pd.DataFrame([8,8,1,2], index=['a', 'b', 'c', 'd'])
 
# make the plot
df.plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000237C97FBF98>],
#       dtype=object)
